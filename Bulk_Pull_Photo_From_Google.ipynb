# %%
import pandas as pd
import requests
from api_keys import google_api_key

# %%
farming_list = pd.read_csv("Farming_list_sample.csv")

farming_list.head()
# Out:
#            Status      OWNERFIRST OWNERLAST               Fullname  \
# 0  Owner Occupied       Augustine     Scott        Augustine Scott
# 1  Owner Occupied  Dana & Stephen    Cilono  Dana & Stephen Cilono
# 2  Owner Occupied           David  Williams         David Williams
# 3  Owner Occupied    Duke & Helen   Roberts   Duke & Helen Roberts
# 4  Owner Occupied             Efe   Oghorie            Efe Oghorie
#
#    SITENUMBER       SITESTREET SITECITY  SITEZIP MAILNUMBER       MAILSTREET  \
# 0      4303.0  Aberfoil Avenue  Oakland    94605       4303  Aberfoil Avenue
# 1      4222.0  Aberfoil Avenue  Oakland    94605       4222  Aberfoil Avenue
# 2      4200.0  Aberfoil Avenue  Oakland    94605       4200  Aberfoil Avenue
# 3      4201.0  Aberfoil Avenue  Oakland    94605       4201  Aberfoil Avenue
# 4      4220.0  Aberfoil Avenue  Oakland    94605       4220  Aberfoil Avenue
#
#    ... TOPOGRPH SWRTYPE  WTRSRC GASSVC GRNDCVR  AGRICPRV  NULL3   INTRTYPE1  \
# ...

# %%
farming_list = farming_list[["Fullname", "SITENUMBER", "SITESTREET", "SITECITY", "SITEZIP"]]
farming_list.head()
# Out:
#                 Fullname  SITENUMBER       SITESTREET SITECITY  SITEZIP
# 0        Augustine Scott      4303.0  Aberfoil Avenue  Oakland    94605
# 1  Dana & Stephen Cilono      4222.0  Aberfoil Avenue  Oakland    94605
# 2         David Williams      4200.0  Aberfoil Avenue  Oakland    94605
# 3   Duke & Helen Roberts      4201.0  Aberfoil Avenue  Oakland    94605
# 4            Efe Oghorie      4220.0  Aberfoil Avenue  Oakland    94605

# %%
farming_list1 = farming_list.rename(columns = {"Fullname": "Owner_Name",
                                             "SITENUMBER": "Street_Number",
                                             "SITESTREET": "Street_Name",
                                             "SITECITY": "City",
                                             "SITEZIP": "Zipcode"})
farming_list1.head()
# Out:
#               Owner_Name  Street_Number      Street_Name     City  Zipcode
# 0        Augustine Scott         4303.0  Aberfoil Avenue  Oakland    94605
# 1  Dana & Stephen Cilono         4222.0  Aberfoil Avenue  Oakland    94605
# 2         David Williams         4200.0  Aberfoil Avenue  Oakland    94605
# 3   Duke & Helen Roberts         4201.0  Aberfoil Avenue  Oakland    94605
# 4            Efe Oghorie         4220.0  Aberfoil Avenue  Oakland    94605

# %%
farming_list1.dropna(how = "any", inplace = True)
farming_list1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 867 entries, 0 to 867
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Owner_Name     867 non-null    object
#  1   Street_Number  867 non-null    float64
#  2   Street_Name    867 non-null    object
#  3   City           867 non-null    object
#  4   Zipcode        867 non-null    int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 40.6+ KB

# %%
farming_list["Street_Number"] = farming_list["Street_Number"].apply(lambda x: str(x))
farming_list["Zipcode"] = farming_list["Zipcode"].apply(lambda x: str(x))

farming_list.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Street_Number'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
farming_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 868 entries, 0 to 867
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Fullname    868 non-null    object
#  1   SITENUMBER  867 non-null    float64
#  2   SITESTREET  868 non-null    object
#  3   SITECITY    868 non-null    object
#  4   SITEZIP     868 non-null    int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 34.0+ KB
